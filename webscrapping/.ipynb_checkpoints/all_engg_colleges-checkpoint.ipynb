# %%
from urllib.request import urlopen as ureq
from bs4 import BeautifulSoup as soup
import requests
import mechanize

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options 
#from selenium.webdriver.firefox.options import Options

# %%
chrome_options = webdriver.ChromeOptions()  
#options = Options()
#options.add_argument("--headless")
chrome_options.add_argument("headless")  
driver = webdriver.Chrome('C:/Users/hp/Downloads/Compressed/chromedriver_win32_4/chromedriver.exe',chrome_options=chrome_options) 
#driver = webdriver.Firefox(options=options)

# %%
mainpage_url = "http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPKPN4"
base_url='https://cee.kerala.gov.in/collegelist/main/'
attrib=["engg_G","engg_N","engg_S"]

# %%
links=[]

# %%
u_client= ureq(mainpage_url)
mainpage_html=u_client.read()
u_client.close()
mainpage_soup=soup(mainpage_html, 'html.parser')

# %%
container=mainpage_soup.findAll('tr',{"class":'alternate1'})

# %%
for i in range(len(container)):
    links.append(container[i].td.a['href'])

# %%
links
# Out:
# ['http://www.studyguideindia.com/Colleges/Engineering/a-m-reddy-memorial-college-of-engineering-tech.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/a-m-r-institute-of-technology.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/ar-college-of-engineering-and-technology.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/a-r-j-college-of-engineering-technology.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/aalim-muhammed-salegh-academy-of-architecture.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/aarupadai-veedu-institute-technology.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/abdul-kalam-institute-of-technological-sciences.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/abss-institute-of-technology.html',
#  'http://www.studyguideindia.com/Colleges/Engineering/academy-of-engineering-ed-research-inst-of-tech.html',
# ...

# %%
buttons=mainpage_soup.findAll('p',{'class':'paging aligncenter'})[0].findAll('a',{'class':'link'})
buttons.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-8e2a1245e534> in <module>()
#       1 buttons=mainpage_soup.findAll('p',{'class':'paging aligncenter'})[0].findAll('a',{'class':'link'})
# ----> 2 buttons.text
#
# ~\AppData\Local\conda\conda\envs\p35tf\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
mainpage_url=buttons[-1]['href']

# %%
next_links=[mainpage_url]

# %%
while(True):
    main_url=next_links[-1]
    u_client= ureq(main_url)
    main_html=u_client.read()
    u_client.close()
    main_soup=soup(main_html, 'html.parser')
    buttons=main_soup.findAll('p',{'class':'paging aligncenter'})[0].findAll('a',{'class':'link'})
    if(buttons[-1].text=='77'):
        break;
    next_links.append(buttons[-1]['href'])
    print(next_links[-1])
    print(buttons[0].text)
# Out:
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0
# 2
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPKPN4
# << Prev
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0
# 2
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPKPN4
# << Prev
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0
# 2
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPKPN4
# << Prev
# http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0
# 2
# ...

# %%
next_links
# Out:
# ['http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
#  'http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
#  'http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
#  'http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
#  'http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
#  'http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
#  'http://www.studyguideindia.com/Colleges/Engineering/default.asp?College_type=JNKPNQL0&hdninttype=JNKPNQL0&sort=&by=&page=JNKPNQL0',
# ...
